# %% [markdown]
# ## Import

# %%
from faker import Faker
import pandas as pd
import random

# %% [markdown]
# ## Generate

# %%
def create_synthetic_data():
    fake = Faker('en_TH')
    SEED = 92
    random.seed(SEED)
    fake.seed_instance(SEED)

    campaign_df = pd.read_csv('Data/Campaign/Campaign_Data.csv')
    campaign_ids = campaign_df['Campaign_ID'].tolist()

    objective_df =

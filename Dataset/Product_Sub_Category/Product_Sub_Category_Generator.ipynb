# %% [markdown]
# # Synthetic Data Generator
#
# This project generates realistic synthetic data for analytics practice, SQL testing, and portfolio projects.

# %% [markdown]
# ## Import

# %%
from faker import Faker
import pandas as pd

# %% [markdown]
# ## Generate

# %%
def create_sub_category_data():

    fake = Faker('en_TH')

    # seed 92 is initialized to guarantee deterministic record generation
    SEED = 92
    fake.seed_instance(SEED)

    # Load Product Category data
    product_category_df = pd.read_csv('../Product_Category/Product_Category_Data.csv')

    # Convert date
    product_category_df['Created_At'] = pd.to_datetime(product_category_df['Created_At']).dt.date

    # Create dictionaries for quick lookups
    category_id_map = dict(
        zip(
            product_category_df['Category_Name'],
            product_category_df['Category_ID']
        )
    )

    category_created_at_map = dict(
        zip(
            product_category_df['Category_Name'],
            product_category_df['Created_At']
        )
    )

    # Product Category -> Sub Category Mapping
    sub_category_mapping = {
        "Mattress": [
            "Foam",
            "Spring",
            "Pocket Spring"
        ],
        "Bedsheet": [
            "Cotton",
            "Polyester",
            "Linen"
        ],
        "Pillow": [
            "Cotton",
            "Feather",
            "Polyester"
        ],
        "Bolster": [
            "Cotton",
            "Feather",
            "Polyester"
        ],
        "Blanket": [
            "Cotton",
            "Flannel",
            "Fleece"
        ]
    }

    # Lists
    Sub_Category_ID = []
    Sub_Category_Name = []
    Category_ID = []
    Created_At = []

    # Generate Sub Categories
    for category, sub_categories in sub_category_mapping.items():

        for sub_category in sub_categories:

            prefix_id = 'SUBCAT_'
            Sub_Category_ID.append(prefix_id + fake.unique.uuid4()[:4])

            Sub_Category_Name.append(sub_category)

            Category_ID.append(category_id_map[category])

            # Sub category cannot exist before parent category
            Created_At.append(category_created_at_map[category])

    # Create DataFrame
    Product_Sub_Category = pd.DataFrame({
        'Sub_Category_ID': Sub_Category_ID,
        'Sub_Category_Name': Sub_Category_Name,
        'Category_ID': Category_ID,
        'Created_At': Created_At
    })

    return Product_Sub_Category

# %% [markdown]
# ## Preview

# %%
Product_Sub_Category = create_sub_category_data()
Product_Sub_Category
# Out:
#    Sub_Category_ID Sub_Category_Name  Category_ID  Created_At
# 0      SUBCAT_8cd2              Foam  PROCAT_8cd2  2021-01-01
# 1      SUBCAT_4414            Spring  PROCAT_8cd2  2021-01-01
# 2      SUBCAT_e09a     Pocket Spring  PROCAT_8cd2  2021-01-01
# 3      SUBCAT_182e            Cotton  PROCAT_4414  2021-01-01
# 4      SUBCAT_28ad         Polyester  PROCAT_4414  2021-01-01
# 5      SUBCAT_13fa             Linen  PROCAT_4414  2021-01-01
# 6      SUBCAT_56a3            Cotton  PROCAT_e09a  2024-01-01
# 7      SUBCAT_06ac           Feather  PROCAT_e09a  2024-01-01
# 8      SUBCAT_ccc4         Polyester  PROCAT_e09a  2024-01-01
# 9      SUBCAT_28ce            Cotton  PROCAT_182e  2024-01-01
# 10     SUBCAT_ba3a           Feather  PROCAT_182e  2024-01-01
# 11     SUBCAT_acd0         Polyester  PROCAT_182e  2024-01-01
# 12     SUBCAT_1e64            Cotton  PROCAT_28ad  2024-01-01
# 13     SUBCAT_27a0           Flannel  PROCAT_28ad  2024-01-01
# 14     SUBCAT_6ee7            Fleece  PROCAT_28ad  2024-01-01
